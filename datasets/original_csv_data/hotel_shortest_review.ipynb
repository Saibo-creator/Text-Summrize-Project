# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
test=pd.read_csv('./test.csv')
train=pd.read_csv('./train.csv')
dev=pd.read_csv('./dev.csv')
'''executed in 2m 49s'''
# Out:
# 'executed in 2m 49s'

# %%
"executed in 51.6s"
tot=pd.concat([dev,test,train])

# %%
tot['text'].apply(len).sort_values().head(20)
# Out:
# 1540616     9
# 588528     14
# 1579838    16
# 1646008    17
# 588531     19
# 588530     21
# 974170     21
# 1204894    22
# 1574450    23
# 951322     24
# 195166     25
# 1099407    26
# 429839     30
# 62605      32
# 1148234    32
# 225597     33
# 601166     33
# 909131     34
# 384827     39
# 885189     39
# Name: text, dtype: int64

# %%
plt.figure(figsize=(20,7))

plt.hist(tot['text'].apply(len),bins=100,range=(0,2000));


plt.xlabel("number of letters")
plt.ylabel("counts")
plt.title("Histogram of hotel review lenth")
plt.savefig('./Histogram of hotel review lenth')
plt.show()

# %%
yelp=pd.read_json('../yelp_dataset/review.json',lines=True)

# %%
yelp['text'].apply(len).sort_values().head(20)
